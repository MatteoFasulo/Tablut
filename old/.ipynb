# %%
import pandas as pd

# %%
pd.read_excel('risultati_0.xls')
# Out:
#                Nome squadra  Girone  Numero Nome giocatore
# 0                    Arthur       1     NaN         Arthur
# 1        Artificial Failure       1     NaN     Artificial
# 2            A Simplex Mind       1     NaN     ASimplexMi
# 3                    Beluga       1     NaN         Beluga
# 4      NullPointerException       1     NaN        Cliente
# 5                FunSociety       1     NaN     FunSociety
# 6         HowIMetYourTablut       1     NaN         random
# 7                    UniOne       1     NaN         UniOne
# 8               Drop Tablut       2     NaN     DropTablut
# 9                    Algise       2     NaN         Algise
# 10             Gionnino9000       2     NaN      Tavoletta
# 11                     ALFE       2     NaN           ALFE
# 12              WhatTheFork       2     NaN      PlayerWTF
# 13        Bug Tablut Theory       2     NaN      BugTablut
# 14  Artificial Inability AI       2     NaN     AInability
# ...
